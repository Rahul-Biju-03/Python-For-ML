# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA
import pandas as pd
import seaborn as sns

# %%
# Loading the test data

url = 'https://query.data.world/s/ksxft7lhmbxpihskwsngwhpuul6lye'
col_names = ['target','F1R', 'F1S', 'F2R', 'F2S', 'F3R', 'F3S', 'F4R', 'F4S', 'F5R','F5S','F6R','F6S','F7R','F7S','F8R','F8S','F9R','F9S','F10R',
    'F10S',  'F11R','F11S','F12R','F12S','F13R','F13S','F14R','F14S','F15R','F15S','F16R','F16S','F17R','F17S','F18R','F18S','F19R','F19S',   'F20R',
    'F20S','F21R','F21S','F22R','F22S']
spectf_df_test= pd.read_table(url,sep=',',names=col_names)

# %%
spectf_df_test
# Out:
#     target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...  F18R  F18S  \
# 0        1   59   52   70   67   73   66   72   61   58  ...    66    56
# 1        1   72   62   69   67   78   82   74   65   69  ...    65    71
# 2        1   71   62   70   64   67   64   79   65   70  ...    73    70
# 3        1   69   71   70   78   61   63   67   65   59  ...    61    61
# 4        1   70   66   61   66   61   58   69   69   72  ...    67    69
# ..     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 75       0   70   75   72   72   67   71   71   78   63  ...    66    67
# 76       0   59   57   67   71   66   68   68   70   56  ...    62    64
# 77       0   67   64   73   75   77   77   74   70   65  ...    61    64
# 78       0   68   65   72   72   47   74   76   74   67  ...    64    69
# 79       0   66   54   69   66   69   69   75   72   63  ...    69    65
#
#     F19R  F19S  F20R  F20S  F21R  F21S  F22R  F22S
# 0     62    56    72    62    74    74    64    67
# 1     63    60    69    73    67    71    56    58
# 2     66    65    64    55    61    41    51    46
# 3     66    65    72    73    68    68    59    63
# 4     70    66    70    64    60    55    49    41
# ..   ...   ...   ...   ...   ...   ...   ...   ...
# 75    68    70    70    71    64    67    56    54
# 76    56    53    71    68    64    63    56    56
# 77    65    60    68    75    74    80    67    68
# 78    71    73    73    75    68    56    58    44
# 79    65    64    67    69    71    68    59    59
#
# [80 rows x 45 columns]

# %%
# Loading the Train data

url = 'https://query.data.world/s/cuqtpuoewpxysusrt5z4igihjah4xo'
col_names = ['target','F1R', 'F1S', 'F2R', 'F2S', 'F3R', 'F3S', 'F4R', 'F4S', 'F5R','F5S','F6R','F6S','F7R','F7S','F8R','F8S','F9R','F9S','F10R',
    'F10S',  'F11R','F11S','F12R','F12S','F13R','F13S','F14R','F14S','F15R','F15S','F16R','F16S','F17R','F17S','F18R','F18S','F19R','F19S',   'F20R',
    'F20S','F21R','F21S','F22R','F22S']
spectf_df= pd.read_table(url,sep=',',names=col_names)

# %%
spectf_df
# Out:
#      target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...  F18R  F18S  \
# 0         1   67   68   73   78   65   63   67   60   63  ...    61    56
# 1         1   75   74   71   71   62   58   70   64   71  ...    66    62
# 2         1   83   64   66   67   67   74   74   72   64  ...    67    64
# 3         1   72   66   65   65   64   61   71   78   73  ...    69    68
# 4         1   62   60   69   61   63   63   70   68   70  ...    66    66
# ..      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 182       0   74   69   75   70   70   74   77   77   65  ...    66    67
# 183       0   72   61   64   66   64   59   68   66   76  ...    69    64
# 184       0   75   73   72   77   68   67   76   73   67  ...    70    67
# 185       0   59   62   72   74   66   66   74   76   63  ...    65    71
# 186       0   64   66   68   71   62   64   74   73   63  ...    70    69
#
#      F19R  F19S  F20R  F20S  F21R  F21S  F22R  F22S
# 0      76    75    74    77    76    74    59    68
# 1      68    69    69    66    64    58    57    52
# 2      69    63    68    54    65    64    43    42
# 3      68    63    71    72    65    63    58    60
# 4      58    56    72    73    71    64    49    42
# ..    ...   ...   ...   ...   ...   ...   ...   ...
# 182    63    61    71    68    66    65    54    57
# 183    67    71    69    68    65    73    56    52
# 184    72    71    79    75    77    75    67    71
# 185    67    69    77    78    77    76    70    70
# 186    68    65    75    72    62    64    57    54
#
# [187 rows x 45 columns]

# %%
spectf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 45 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  187 non-null    int64
#  1   F1R     187 non-null    int64
#  2   F1S     187 non-null    int64
#  3   F2R     187 non-null    int64
#  4   F2S     187 non-null    int64
#  5   F3R     187 non-null    int64
#  6   F3S     187 non-null    int64
#  7   F4R     187 non-null    int64
#  8   F4S     187 non-null    int64
#  9   F5R     187 non-null    int64
#  10  F5S     187 non-null    int64
#  11  F6R     187 non-null    int64
#  12  F6S     187 non-null    int64
#  13  F7R     187 non-null    int64
#  14  F7S     187 non-null    int64
#  15  F8R     187 non-null    int64
#  16  F8S     187 non-null    int64
#  17  F9R     187 non-null    int64
#  18  F9S     187 non-null    int64
#  19  F10R    187 non-null    int64
#  20  F10S    187 non-null    int64
#  21  F11R    187 non-null    int64
#  22  F11S    187 non-null    int64
#  23  F12R    187 non-null    int64
#  24  F12S    187 non-null    int64
#  25  F13R    187 non-null    int64
#  26  F13S    187 non-null    int64
#  27  F14R    187 non-null    int64
#  28  F14S    187 non-null    int64
#  29  F15R    187 non-null    int64
#  30  F15S    187 non-null    int64
#  31  F16R    187 non-null    int64
#  32  F16S    187 non-null    int64
#  33  F17R    187 non-null    int64
#  34  F17S    187 non-null    int64
#  35  F18R    187 non-null    int64
#  36  F18S    187 non-null    int64
#  37  F19R    187 non-null    int64
#  38  F19S    187 non-null    int64
#  39  F20R    187 non-null    int64
#  40  F20S    187 non-null    int64
#  41  F21R    187 non-null    int64
#  42  F21S    187 non-null    int64
#  43  F22R    187 non-null    int64
#  44  F22S    187 non-null    int64
# dtypes: int64(45)
# memory usage: 65.9 KB

# %%
spectf_df.describe()
# Out:
#            target         F1R         F1S         F2R         F2S         F3R  \
# count  187.000000  187.000000  187.000000  187.000000  187.000000  187.000000
# mean     0.919786   65.128342   63.786096   68.304813   68.320856   63.818182
# std      0.272353    8.961963   10.157746    6.849231    9.046697    9.569165
# min      0.000000   23.000000   21.000000   38.000000   34.000000   21.000000
# 25%      1.000000   61.000000   58.500000   64.000000   65.000000   60.000000
# 50%      1.000000   66.000000   65.000000   69.000000   70.000000   65.000000
# 75%      1.000000   71.000000   70.000000   73.000000   74.000000   70.000000
# max      1.000000   83.000000   80.000000   82.000000   84.000000   82.000000
#
#               F3S         F4R         F4S         F5R  ...        F18R  \
# count  187.000000  187.000000  187.000000  187.000000  ...  187.000000
# mean    62.374332   69.352941   68.534759   62.839572  ...   63.358289
# std     10.069062    9.513631   10.614082    9.604879  ...    8.673589
# min     25.000000   21.000000   20.000000   12.000000  ...   18.000000
# 25%     59.000000   67.000000   66.000000   60.500000  ...   61.500000
# 50%     64.000000   71.000000   71.000000   65.000000  ...   66.000000
# 75%     69.000000   75.000000   75.000000   68.000000  ...   69.000000
# max     79.000000   85.000000   81.000000   76.000000  ...   76.000000
#
#              F18S        F19R        F19S        F20R        F20S        F21R  \
# count  187.000000  187.000000  187.000000  187.000000  187.000000  187.000000
# mean    61.695187   65.090909   63.850267   64.390374   62.187166   60.770053
# std     12.025874    7.980977    9.171545   13.241857   13.691778   15.516746
# min     14.000000   33.000000   18.000000   11.000000    6.000000    5.000000
# 25%     60.000000   60.500000   59.000000   61.000000   58.000000   55.500000
# 50%     65.000000   66.000000   66.000000   68.000000   66.000000   66.000000
# 75%     69.000000   70.000000   70.000000   73.000000   71.000000   72.000000
# max     77.000000   80.000000   79.000000   81.000000   81.000000   82.000000
#
#              F21S        F22R        F22S
# count  187.000000  187.000000  187.000000
# mean    58.406417   51.128342   48.593583
# std     16.194568   13.350712   15.087756
# min      8.000000   13.000000    4.000000
# 25%     53.500000   44.000000   42.000000
# 50%     63.000000   55.000000   52.000000
# 75%     69.000000   60.000000   60.000000
# max     82.000000   82.000000   71.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# # Checking whether the dataset is balanced or not

# %%
#Train Data balance check
sns.countplot(x='target',data=spectf_df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
# Test data balance check
sns.countplot(x='target',data=spectf_df_test)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
corr_df=spectf_df.corr()
plt.figure(figsize=(18,12))
sns.heatmap(corr_df)
# Out:
# <Axes: >

# %% [markdown]
# # Split labels and features

# %%
traget=spectf_df['target']

# %%
spectf_df.drop('target', axis=1, inplace=True) #drop target which is a variable column
spectf_df
# Out:
#      F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  F5S  ...  F18R  F18S  F19R  \
# 0     67   68   73   78   65   63   67   60   63   62  ...    61    56    76
# 1     75   74   71   71   62   58   70   64   71   68  ...    66    62    68
# 2     83   64   66   67   67   74   74   72   64   68  ...    67    64    69
# 3     72   66   65   65   64   61   71   78   73   69  ...    69    68    68
# 4     62   60   69   61   63   63   70   68   70   65  ...    66    66    58
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 182   74   69   75   70   70   74   77   77   65   67  ...    66    67    63
# 183   72   61   64   66   64   59   68   66   76   66  ...    69    64    67
# 184   75   73   72   77   68   67   76   73   67   65  ...    70    67    72
# 185   59   62   72   74   66   66   74   76   63   67  ...    65    71    67
# 186   64   66   68   71   62   64   74   73   63   67  ...    70    69    68
#
#      F19S  F20R  F20S  F21R  F21S  F22R  F22S
# 0      75    74    77    76    74    59    68
# 1      69    69    66    64    58    57    52
# 2      63    68    54    65    64    43    42
# 3      63    71    72    65    63    58    60
# 4      56    72    73    71    64    49    42
# ..    ...   ...   ...   ...   ...   ...   ...
# 182    61    71    68    66    65    54    57
# 183    71    69    68    65    73    56    52
# 184    71    79    75    77    75    67    71
# 185    69    77    78    77    76    70    70
# 186    65    75    72    62    64    57    54
#
# [187 rows x 44 columns]

# %%
traget_test=spectf_df_test['target']

# %%
spectf_df_test.drop('target', axis=1, inplace=True)
spectf_df_test
# Out:
#     F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  F5S  ...  F18R  F18S  F19R  \
# 0    59   52   70   67   73   66   72   61   58   52  ...    66    56    62
# 1    72   62   69   67   78   82   74   65   69   63  ...    65    71    63
# 2    71   62   70   64   67   64   79   65   70   69  ...    73    70    66
# 3    69   71   70   78   61   63   67   65   59   59  ...    61    61    66
# 4    70   66   61   66   61   58   69   69   72   68  ...    67    69    70
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 75   70   75   72   72   67   71   71   78   63   67  ...    66    67    68
# 76   59   57   67   71   66   68   68   70   56   62  ...    62    64    56
# 77   67   64   73   75   77   77   74   70   65   62  ...    61    64    65
# 78   68   65   72   72   47   74   76   74   67   66  ...    64    69    71
# 79   66   54   69   66   69   69   75   72   63   62  ...    69    65    65
#
#     F19S  F20R  F20S  F21R  F21S  F22R  F22S
# 0     56    72    62    74    74    64    67
# 1     60    69    73    67    71    56    58
# 2     65    64    55    61    41    51    46
# 3     65    72    73    68    68    59    63
# 4     66    70    64    60    55    49    41
# ..   ...   ...   ...   ...   ...   ...   ...
# 75    70    70    71    64    67    56    54
# 76    53    71    68    64    63    56    56
# 77    60    68    75    74    80    67    68
# 78    73    73    75    68    56    58    44
# 79    64    67    69    71    68    59    59
#
# [80 rows x 44 columns]

# %% [markdown]
# Steps of PCA
# 1. Standarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()#instantiate
 
# compute the mean and standard which will be used in the next command

spect_df=scaler.fit_transform(spectf_df)# fit and transform can be applied together and I leave that for simple exercise
# we can check the minimum and maximum of the scaled features which we expect to be 0 and 1

spect_df_test=scaler.fit_transform(spectf_df_test)

# %%
traget
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 182    0
# 183    0
# 184    0
# 185    0
# 186    0
# Name: target, Length: 187, dtype: int64

# %%
# Time taken to train

import time
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
start=time.time()


logreg.fit(spect_df,traget)
end=time.time()


traintime=end-start
print('training time for logreg is:  ',traintime)
# Out:
# training time for logreg is:   0.009706497192382812

# %%
y_pred_class=logreg.predict(spect_df_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_pred_class,traget_test)
# Out:
# 0.5125

# %%
spect_df
# Out:
# array([[ 0.20940529,  0.41596002,  0.68734602, ...,  0.96547463,
#          0.59118869,  1.28968911],
#        [ 1.10446332,  1.00822796,  0.39455854, ..., -0.02516326,
#          0.44098178,  0.22637971],
#        [ 1.99952135,  0.02111472, -0.33741018, ...,  0.34632595,
#         -0.61046658, -0.43818867],
#        ...,
#        [ 1.10446332,  0.90951664,  0.54095228, ...,  1.0273895 ,
#          1.19201632,  1.48905963],
#        [-0.68565274, -0.17630793,  0.54095228, ...,  1.08930437,
#          1.41732668,  1.42260279],
#        [-0.12624147,  0.21853737, -0.04462269, ...,  0.34632595,
#          0.44098178,  0.35929338]])

# %% [markdown]
# # Apply PCA to logreg model

# %%
from sklearn.decomposition import PCA

pca=PCA()
pca.fit(spect_df)
# Out:
# PCA()

# %%
spect_df
# Out:
# array([[ 0.20940529,  0.41596002,  0.68734602, ...,  0.96547463,
#          0.59118869,  1.28968911],
#        [ 1.10446332,  1.00822796,  0.39455854, ..., -0.02516326,
#          0.44098178,  0.22637971],
#        [ 1.99952135,  0.02111472, -0.33741018, ...,  0.34632595,
#         -0.61046658, -0.43818867],
#        ...,
#        [ 1.10446332,  0.90951664,  0.54095228, ...,  1.0273895 ,
#          1.19201632,  1.48905963],
#        [-0.68565274, -0.17630793,  0.54095228, ...,  1.08930437,
#          1.41732668,  1.42260279],
#        [-0.12624147,  0.21853737, -0.04462269, ...,  0.34632595,
#          0.44098178,  0.35929338]])

# %% [markdown]
# # Min number of components we need

# %%
pca.explained_variance_ratio_[:15].sum()
# Out:
# 0.8848609248504705

# %%
pca.explained_variance_ratio_ # value of each PCA. There are 44 PCA.
# Out:
# array([0.32429332, 0.13194552, 0.09995418, 0.05297254, 0.04083738,
#        0.0350932 , 0.03285052, 0.03090813, 0.02931535, 0.02480157,
#        0.02055687, 0.0178984 , 0.01605292, 0.01482171, 0.01255932,
#        0.01193276, 0.01057778, 0.00910103, 0.0075903 , 0.00714458,
#        0.00662498, 0.00642303, 0.00564494, 0.00525405, 0.00448752,
#        0.00408326, 0.00389785, 0.00372295, 0.00341504, 0.00296922,
#        0.00276063, 0.00259317, 0.00234468, 0.00209592, 0.00182189,
#        0.00177844, 0.00166454, 0.00155031, 0.00121086, 0.00111697,
#        0.00102268, 0.00096622, 0.00079125, 0.00055225])

# %%
pca.explained_variance_ratio_[:15].sum()
# Out:
# 0.8848609248504705

# %%
# 1st PC

pca.explained_variance_ratio_[:2].sum()
# Out:
# 0.45623884368506873

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.32429332, 0.45623884, 0.55619302, 0.60916556, 0.65000294,
#        0.68509614, 0.71794666, 0.74885479, 0.77817014, 0.80297171,
#        0.82352857, 0.84142697, 0.85747989, 0.8723016 , 0.88486092,
#        0.89679368, 0.90737146, 0.91647249, 0.92406278, 0.93120736,
#        0.93783235, 0.94425537, 0.94990031, 0.95515437, 0.95964188,
#        0.96372515, 0.967623  , 0.97134594, 0.97476098, 0.9777302 ,
#        0.98049083, 0.983084  , 0.98542868, 0.9875246 , 0.98934649,
#        0.99112493, 0.99278947, 0.99433978, 0.99555064, 0.9966676 ,
#        0.99769028, 0.9986565 , 0.99944775, 1.        ])

# %%
# Relationship b/w PC and variance
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.annotate('15', xy=(15,.90))
# Out:
# Text(15, 0.9, '15')

# %%
spect_df
# Out:
# array([[ 0.20940529,  0.41596002,  0.68734602, ...,  0.96547463,
#          0.59118869,  1.28968911],
#        [ 1.10446332,  1.00822796,  0.39455854, ..., -0.02516326,
#          0.44098178,  0.22637971],
#        [ 1.99952135,  0.02111472, -0.33741018, ...,  0.34632595,
#         -0.61046658, -0.43818867],
#        ...,
#        [ 1.10446332,  0.90951664,  0.54095228, ...,  1.0273895 ,
#          1.19201632,  1.48905963],
#        [-0.68565274, -0.17630793,  0.54095228, ...,  1.08930437,
#          1.41732668,  1.42260279],
#        [-0.12624147,  0.21853737, -0.04462269, ...,  0.34632595,
#          0.44098178,  0.35929338]])

# %%
x_pca=PCA(n_components=15)
spect_df_pca=x_pca.fit_transform(spect_df)
spect_df_pca_test=x_pca.fit_transform(spect_df_test)

# %%
spect_df_pca
# Out:
# array([[ 2.83517148, -2.06288369,  1.49743484, ..., -0.66069308,
#         -0.40920275,  0.28999989],
#        [ 2.02888194,  0.17127715,  1.38272881, ...,  0.59103486,
#         -0.91463005,  0.20895565],
#        [ 2.25645259, -0.63169171,  1.1764974 , ...,  0.70583715,
#         -0.69063094,  1.23982431],
#        ...,
#        [ 4.22897407, -0.23809035,  0.48986165, ...,  0.00661014,
#         -0.01790293,  0.63989674],
#        [ 3.05115832, -1.03288021, -0.52410351, ..., -1.11647464,
#          0.21881099, -0.8017479 ],
#        [ 2.95132756, -0.32161374,  0.2337291 , ..., -0.38070769,
#         -0.32752065,  0.2512389 ]])

# %%
pca_corr=pd.DataFrame(spect_df_pca).corr()
plt.figure(figsize=(18,12))
sns.heatmap(pca_corr,annot=True)
# Out:
# <Axes: >

# %%
cols=['F1R', 'F1S', 'F2R', 'F2S', 'F3R', 'F3S', 'F4R', 'F4S', 'F5R','F5S','F6R','F6S','F7R','F7S','F8R','F8S','F9R','F9S','F10R',
    'F10S',  'F11R','F11S','F12R','F12S','F13R','F13S','F14R','F14S','F15R','F15S','F16R','F16S','F17R','F17S','F18R','F18S','F19R','F19S',   'F20R',
    'F20S','F21R','F21S','F22R','F22S']

# %%
pca_Df=pd.DataFrame(x_pca.components_, columns=cols)
pca_Df
# Out:
#          F1R       F1S       F2R       F2S       F3R       F3S       F4R  \
# 0  -0.035898  0.017530  0.111833  0.111480  0.017346  0.037067  0.002738
# 1  -0.150338 -0.173713 -0.072706 -0.066390  0.049838  0.119820 -0.132181
# 2   0.086964  0.126971  0.235234  0.285529  0.127679  0.204450  0.059947
# 3   0.188783  0.378312  0.071752  0.099683 -0.019744  0.252534  0.071195
# 4   0.112765 -0.115799 -0.027131 -0.166600  0.369932  0.090385  0.144873
# 5   0.108223  0.008476 -0.087580 -0.136153 -0.252898 -0.125292 -0.206321
# 6   0.041795  0.022909  0.265969  0.134934  0.225600  0.135687  0.074028
# 7   0.286378  0.056788 -0.052698 -0.029165  0.175911 -0.040909  0.490332
# 8   0.363232  0.085022  0.344221  0.257188 -0.056993 -0.283664  0.052585
# 9   0.116937  0.071325  0.073322  0.030309  0.108706 -0.173646  0.120528
# 10 -0.316784 -0.224664 -0.027307 -0.135665  0.050071  0.117298  0.484298
# 11  0.077027 -0.043197 -0.107165 -0.026346  0.381057  0.356350 -0.056293
# 12  0.237026 -0.163232  0.235572 -0.240957 -0.156120 -0.121395  0.085627
# 13 -0.127560 -0.188527  0.078084 -0.049547 -0.091840 -0.279871  0.104422
# 14 -0.333550  0.190246  0.067204 -0.026001  0.407341 -0.261887 -0.095021
#
#          F4S       F5R       F5S  ...      F18R      F18S      F19R      F19S  \
# 0   0.047917  0.172289  0.177385  ...  0.172270  0.212356  0.136592  0.176232
# 1  -0.059531 -0.215582 -0.182137  ... -0.086452 -0.104230 -0.127307 -0.170026
# 2   0.060883  0.021773  0.008242  ... -0.245296 -0.185675  0.119961  0.134840
# 3   0.397000 -0.071429  0.182330  ...  0.010185  0.113113 -0.221099 -0.068866
# 4  -0.195251  0.277002  0.193336  ... -0.034682 -0.106067 -0.139714 -0.144355
# 5  -0.081701  0.037327  0.086344  ...  0.037434  0.048227  0.098509  0.105470
# 6  -0.107837 -0.070630 -0.055487  ... -0.182777 -0.148445 -0.167146 -0.105644
# 7   0.199470  0.081010 -0.078072  ... -0.083207 -0.054863  0.144300  0.028698
# 8  -0.162941  0.011666 -0.030597  ...  0.160015  0.022051 -0.242237 -0.242047
# 9   0.021700 -0.011192  0.036586  ...  0.041704  0.078868  0.328393  0.252233
# 10  0.214211 -0.221410 -0.222516  ...  0.202702  0.089245 -0.043310 -0.018420
# 11 -0.351812 -0.047699 -0.012094  ...  0.150333  0.032328  0.097666  0.049552
# 12 -0.143285 -0.150610 -0.164787  ... -0.178227 -0.125623  0.073028  0.176389
# 13 -0.139782  0.093057  0.137771  ... -0.092165  0.017457 -0.262022 -0.144048
# 14 -0.169830 -0.116830  0.043806  ...  0.046512  0.034962  0.003301  0.211979
#
#         F20R      F20S      F21R      F21S      F22R      F22S
# 0   0.204724  0.202868  0.171772  0.153752  0.167514  0.134945
# 1   0.034597 -0.031014  0.238562  0.283494  0.251253  0.298699
# 2  -0.037275  0.003635  0.058486  0.067425  0.032719  0.038059
# 3  -0.133788  0.067314 -0.156113  0.060877 -0.081495  0.044258
# 4  -0.121671 -0.334416  0.052373 -0.020502 -0.089500 -0.067154
# 5  -0.064922 -0.106551 -0.018712  0.024537  0.102224  0.088086
# 6  -0.011159 -0.062472  0.070914  0.068456 -0.015680  0.024007
# 7   0.277380  0.085519  0.095635 -0.011172  0.089447  0.006044
# 8   0.131933 -0.094896 -0.022160 -0.151861 -0.048793 -0.030476
# 9   0.025026 -0.064426  0.174726  0.127754  0.291104  0.280583
# 10 -0.043413 -0.002105 -0.067120 -0.110890 -0.058801 -0.090965
# 11  0.198329  0.268031  0.012283  0.032235 -0.052437 -0.041998
# 12  0.190300  0.069040 -0.051199 -0.068589 -0.040784 -0.059276
# 13  0.326737  0.210944  0.058241  0.098482  0.043858  0.084154
# 14 -0.015411  0.038936 -0.179917 -0.110748 -0.085411  0.024108
#
# [15 rows x 44 columns]

# %%
plt.figure(figsize=(18,12))
sns.heatmap(pca_Df,cmap='RdYlGn', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Your task is to create the logreg model and put PCs as features and check the accuracy and how long it takes to train

# %%
# Time taken to train

import time
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
start=time.time()


logreg.fit(spect_df_pca,traget)
end=time.time()


traintime=end-start
print('training time for logreg is:  ',traintime)
# Out:
# training time for logreg is:   0.011008024215698242

# %%
y_pred_class1=logreg.predict(spect_df_pca_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_pred_class1,traget_test)
# Out:
# 0.5
